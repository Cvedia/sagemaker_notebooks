# %% [markdown]
# ### Install dependencies

# %%
# !pip install boto3 sagemaker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: boto3 in /opt/anaconda3/lib/python3.7/site-packages (1.10.33)
# Requirement already satisfied: sagemaker in /opt/anaconda3/lib/python3.7/site-packages (1.45.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/anaconda3/lib/python3.7/site-packages (from boto3) (0.9.4)
# Requirement already satisfied: botocore<1.14.0,>=1.13.33 in /opt/anaconda3/lib/python3.7/site-packages (from boto3) (1.13.33)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /opt/anaconda3/lib/python3.7/site-packages (from boto3) (0.2.1)
# Requirement already satisfied: scipy>=0.19.0 in /opt/anaconda3/lib/python3.7/site-packages (from sagemaker) (1.3.0)
# Requirement already satisfied: numpy>=1.9.0 in /opt/anaconda3/lib/python3.7/site-packages (from sagemaker) (1.16.4)
# Requirement already satisfied: requests<2.21,>=2.20.0 in /opt/anaconda3/lib/python3.7/site-packages (from sagemaker) (2.20.1)
# Requirement already satisfied: smdebug-rulesconfig==0.1.2 in /opt/anaconda3/lib/python3.7/site-packages (from sagemaker) (0.1.2)
# Requirement already satisfied: protobuf>=3.1 in /opt/anaconda3/lib/python3.7/site-packages (from sagemaker) (3.9.1)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /opt/anaconda3/lib/python3.7/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /opt/anaconda3/lib/python3.7/site-packages (from botocore<1.14.0,>=1.13.33->boto3) (2.8.0)
# Requirement already satisfied: docutils<0.16,>=0.10 in /opt/anaconda3/lib/python3.7/site-packages (from botocore<1.14.0,>=1.13.33->boto3) (0.14)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version >= "3.4" in /opt/anaconda3/lib/python3.7/site-packages (from botocore<1.14.0,>=1.13.33->boto3) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /opt/anaconda3/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (2.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.7/site-packages (from requests<2.21,>=2.20.0->sagemaker) (2019.6.16)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.1->sagemaker) (41.0.1)
# Requirement already satisfied: six>=1.9 in /opt/anaconda3/lib/python3.7/site-packages (from protobuf>=3.1->sagemaker) (1.12.0)

# %% [markdown]
# ### Setup
#
# 1. Create a new endpoint at https://us-east-2.console.aws.amazon.com/sagemaker/home?region=us-east-2#/endpoints then set `ENDPOINT` to it's name.
# 2. You can do inference in a single file or in a entire folder, set the path to it using `INPUT_PATH`

# %%
ENDPOINT = "your_endpoint_name"

# local file or folder
INPUT_PATH = "./examples/neptune/"
# INPUT_PATH = "./drones.jpg"

# %% [markdown]
# ### Run inference
#
# Now that we have set the paths, we will run the images thuru amazon sagemaker's endpoint.
#
# Note: This assumes you have created the endpoint and a IAM access been configured.

# %%
import os
import glob
import json
import boto3
import sagemaker

ALLOWED_EXTENSIONS = set(['png', 'jpg', 'jpeg', 'gif', 'webp', 'bmp'])

def getFiles(base):
    if os.path.isfile(base):
        return [base]
    else:
        return glob.glob(os.path.join(base, '**'), recursive=True)
    
# initalize client
sagemaker = boto3.client(
    'runtime.sagemaker',
    region_name='us-east-2'
)

flist = getFiles(INPUT_PATH)
print("Processing: {} files...".format(len(flist)))

for fpath in flist:
    ext = fpath.split('.')[-1].lower() if '.' in fpath else None
    
    # skip unsupported / invalid file extensions
    if ext is None or ext not in ALLOWED_EXTENSIONS:
        continue
    
    # load input
    with open(fpath, 'rb') as fh:
        payload = fh.read()

    # invoke inference
    result = sagemaker.invoke_endpoint(
            EndpointName=ENDPOINT,
            ContentType='image/{}'.format(ext),
            Body=bytearray(payload))

    # sagemaker request raw response
    # print('sagemaker response:\n\n', result, '\n')

    # inference response
    print('file: {} inference response:\n{}\n'.format(
        fpath,
        json.dumps(json.loads(result['Body'].read().decode()), sort_keys=True, indent=4))
    )
# Out:
# Processing: 29 files...
# file: ./examples/neptune/us_navy_01-0045.jpeg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9060637354850769,
#                 "det_bbox": [
#                     0.27096647024154663,
#                     0.06494076550006866,
#                     0.5437979698181152,
#                     0.21127884089946747
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8617641925811768,
#                 "det_bbox": [
#                     0.16081488132476807,
#                     0.26865750551223755,
#                     0.6129817366600037,
#                     0.4529333710670471
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8095219731330872,
#                 "det_bbox": [
#                     0.001582026481628418,
#                     0.6585724353790283,
#                     0.5677797794342041,
#                     1.0
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
#
# file: ./examples/neptune/rotterdam_barge_transfer-00193.jpeg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.998519241809845,
#                 "det_bbox": [
#                     0.8187111616134644,
#                     0.4372188448905945,
#                     0.8923779726028442,
#                     0.5795409083366394
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9936602711677551,
#                 "det_bbox": [
#                     0.4668154716491699,
#                     0.19541329145431519,
#                     0.5073457956314087,
#                     0.3145105838775635
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9656932950019836,
#                 "det_bbox": [
#                     0.5504603385925293,
#                     0.23216040432453156,
#                     0.5892020463943481,
#                     0.36017149686813354
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.7220653891563416,
#                 "det_bbox": [
#                     0.3952655792236328,
#                     0.4510994851589203,
#                     0.4726119041442871,
#                     0.5979763865470886
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.5969520807266235,
#                 "det_bbox": [
#                     0.03685706853866577,
#                     0.4787137806415558,
#                     0.6343896389007568,
#                     1.0
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
#
# file: ./examples/neptune/MVI_1484_VIS.avi.360.jpg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9995323419570923,
#                 "det_bbox": [
#                     0.416492760181427,
#                     0.1911259889602661,
#                     0.6720080375671387,
#                     0.33553922176361084
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9986697435379028,
#                 "det_bbox": [
#                     0.3318327069282532,
#                     0.32432836294174194,
#                     0.5078202486038208,
#                     0.40639927983283997
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9128535389900208,
#                 "det_bbox": [
#                     0.9481552839279175,
#                     0.05912771821022034,
#                     1.0,
#                     0.3379843533039093
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9004986882209778,
#                 "det_bbox": [
#                     0.0015681330114603043,
#                     0.15798231959342957,
#                     0.04343772679567337,
#                     0.3486348092556
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
#
# file: ./examples/neptune/us_navy_00-0031.jpeg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9271233081817627,
#                 "det_bbox": [
#                     0.4532777667045593,
#                     0.43010401725769043,
#                     0.6246808171272278,
#                     0.5512710213661194
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8465363383293152,
#                 "det_bbox": [
#                     0.31111830472946167,
#                     0.44938209652900696,
#                     0.5933314561843872,
#                     0.6295729279518127
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.7004539966583252,
#                 "det_bbox": [
#                     0.0,
#                     0.522995114326477,
#                     0.5199075937271118,
#                     0.8756555914878845
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
#
# file: ./examples/neptune/rotterdam_barge_transfer-00447.jpeg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9952552914619446,
#                 "det_bbox": [
#                     0.6791882514953613,
#                     0.40034011006355286,
#                     0.7847810983657837,
#                     0.618398904800415
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9938188195228577,
#                 "det_bbox": [
#                     0.4450588524341583,
#                     0.2055504024028778,
#                     0.49461421370506287,
#                     0.33258700370788574
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9886772632598877,
#                 "det_bbox": [
#                     0.2826310992240906,
#                     0.09564508497714996,
#                     0.379575252532959,
#                     0.18622133135795593
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9646762013435364,
#                 "det_bbox": [
#                     0.3846310079097748,
#                     0.46151697635650635,
#                     0.46824637055397034,
#                     0.6099416017532349
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8606354594230652,
#                 "det_bbox": [
#                     0.03412121534347534,
#                     0.5797995328903198,
#                     0.6037760376930237,
#                     0.9931057095527649
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
# file: ./examples/neptune/MVI_1615_VIS.avi.210.jpg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9990155696868896,
#                 "det_bbox": [
#                     0.5585653185844421,
#                     0.31929221749305725,
#                     0.7768892645835876,
#                     0.43661803007125854
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9967834949493408,
#                 "det_bbox": [
#                     0.3287220597267151,
#                     0.32812249660491943,
#                     0.6077862977981567,
#                     0.4339579641819
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9960760474205017,
#                 "det_bbox": [
#                     0.9237715005874634,
#                     0.2617575228214264,
#                     0.9976586699485779,
#                     0.45423462986946106
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9291143417358398,
#                 "det_bbox": [
#                     0.0,
#                     0.3886425495147705,
#                     0.06910789757966995,
#                     0.42536962032318115
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8923971056938171,
#                 "det_bbox": [
#                     0.10499127954244614,
#                     0.39166125655174255,
#                     0.13726790249347687,
#                     0.4293801486492157
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8680487871170044,
#                 "det_bbox": [
#                     0.30694156885147095,
#                     0.39196762442588806,
#                     0.3313443064689636,
#                     0.43103644251823425
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.38235095143318176,
#                 "det_bbox": [
#                     0.06822027266025543,
#                     0.40585383772850037,
#                     0.09454122185707092,
#                     0.4270901381969452
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
#
# file: ./examples/neptune/MVI_1482_VIS.avi.300.jpg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9986893534660339,
#                 "det_bbox": [
#                     0.04388636350631714,
#                     0.07853816449642181,
#                     0.7353813052177429,
#                     0.38364607095718384
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9954521059989929,
#                 "det_bbox": [
#                     0.8522384166717529,
#                     0.25794774293899536,
#                     1.0,
#                     0.33977261185646057
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9875305891036987,
#                 "det_bbox": [
#                     0.0,
#                     0.23702937364578247,
#                     0.08815480768680573,
#                     0.3588729500770569
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9811750650405884,
#                 "det_bbox": [
#                     0.5557645559310913,
#                     0.35534238815307617,
#                     0.6130616664886475,
#                     0.380111962556839
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.960826575756073,
#                 "det_bbox": [
#                     0.7906299233436584,
#                     0.33095619082450867,
#                     0.8959967494010925,
#                     0.382301390171051
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
#
# file: ./examples/neptune/MVI_1486_VIS.avi.150.jpg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 2,
#                 "confidence": 0.9991186261177063,
#                 "det_bbox": [
#                     0.5507645010948181,
#                     0.6077246069908142,
#                     0.6192972660064697,
#                     0.6802664995193481
#                 ],
#                 "label": "buoy",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9995152950286865,
#                 "det_bbox": [
#                     0.6109438538551331,
#                     0.10853100568056107,
#                     0.9134148359298706,
#                     0.2709832489490509
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9994927644729614,
#                 "det_bbox": [
#                     0.0696106106042862,
#                     0.24805103242397308,
#                     0.17199158668518066,
#                     0.29976436495780945
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9989217519760132,
#                 "det_bbox": [
#                     0.15875186026096344,
#                     0.10912823677062988,
#                     0.5308394432067871,
#                     0.29525119066238403
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9977557063102722,
#                 "det_bbox": [
#                     0.5607165694236755,
#                     0.19248458743095398,
#                     0.6269113421440125,
#                     0.26174965500831604
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9947754144668579,
#                 "det_bbox": [
#                     0.5078791379928589,
#                     0.21068492531776428,
#                     0.5573505163192749,
#                     0.2685856223106384
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9921737909317017,
#                 "det_bbox": [
#                     0.7910858988761902,
#                     0.007463589310646057,
#                     1.0,
#                     0.3278452157974243
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9844702482223511,
#                 "det_bbox": [
#                     0.18461744487285614,
#                     0.29607754945755005,
#                     0.22171488404273987,
#                     0.36304718255996704
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9807774424552917,
#                 "det_bbox": [
#                     0.009204728528857231,
#                     0.26277250051498413,
#                     0.07060803472995758,
#                     0.3127804398536682
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }
# file: ./examples/neptune/amsterdam-port-2015-birdseye-00196.jpeg inference response:
# {
#     "input.jpg": {
#         "detections": [
#             {
#                 "classid": 3,
#                 "confidence": 0.9986465573310852,
#                 "det_bbox": [
#                     0.41017016768455505,
#                     0.0,
#                     1.0,
#                     0.963961124420166
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9985509514808655,
#                 "det_bbox": [
#                     0.1884472519159317,
#                     0.46948695182800293,
#                     0.3042043447494507,
#                     0.747360348701477
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9965726137161255,
#                 "det_bbox": [
#                     0.01903175376355648,
#                     0.26153409481048584,
#                     0.051702044904232025,
#                     0.3370131254196167
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9961121678352356,
#                 "det_bbox": [
#                     0.3547793924808502,
#                     0.32679107785224915,
#                     0.4365238845348358,
#                     0.44630420207977295
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9913492202758789,
#                 "det_bbox": [
#                     0.1279270350933075,
#                     0.056613557040691376,
#                     0.1489795595407486,
#                     0.10940206050872803
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9910584092140198,
#                 "det_bbox": [
#                     0.4809660017490387,
#                     0.02391490340232849,
#                     0.5126336812973022,
#                     0.08045807480812073
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9893504977226257,
#                 "det_bbox": [
#                     0.11795593798160553,
#                     0.6018579602241516,
#                     0.16728593409061432,
#                     0.7223835587501526
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9848300218582153,
#                 "det_bbox": [
#                     0.026129841804504395,
#                     0.446738600730896,
#                     0.057512685656547546,
#                     0.5232681632041931
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9831157326698303,
#                 "det_bbox": [
#                     0.8979454636573792,
#                     0.13711662590503693,
#                     0.9452508687973022,
#                     0.1831320971250534
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9820322394371033,
#                 "det_bbox": [
#                     0.16269223392009735,
#                     0.17588824033737183,
#                     0.19364921748638153,
#                     0.23976893723011017
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9787634015083313,
#                 "det_bbox": [
#                     0.21787962317466736,
#                     0.004797531291842461,
#                     0.24471531808376312,
#                     0.04441496729850769
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9702305197715759,
#                 "det_bbox": [
#                     0.6421244740486145,
#                     0.005091574043035507,
#                     0.6854217648506165,
#                     0.0510324165225029
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9657590389251709,
#                 "det_bbox": [
#                     0.2334510236978531,
#                     0.29981696605682373,
#                     0.26868778467178345,
#                     0.37636661529541016
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9557344913482666,
#                 "det_bbox": [
#                     0.015011711977422237,
#                     0.14035265147686005,
#                     0.03491326794028282,
#                     0.19123902916908264
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9468560814857483,
#                 "det_bbox": [
#                     0.5623770952224731,
#                     0.03769920766353607,
#                     0.6064529418945312,
#                     0.11509959399700165
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.9244266748428345,
#                 "det_bbox": [
#                     0.9420371651649475,
#                     0.20174352824687958,
#                     0.9998748302459717,
#                     0.2806132435798645
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8475610017776489,
#                 "det_bbox": [
#                     0.7524146437644958,
#                     0.24374139308929443,
#                     0.8417389988899231,
#                     0.3470327854156494
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.836669921875,
#                 "det_bbox": [
#                     0.45936715602874756,
#                     0.19629475474357605,
#                     0.48326772451400757,
#                     0.23817582428455353
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8188352584838867,
#                 "det_bbox": [
#                     0.0019023353233933449,
#                     0.8086836338043213,
#                     0.024012934416532516,
#                     0.9104759097099304
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.8011969923973083,
#                 "det_bbox": [
#                     0.06732138991355896,
#                     0.3376331925392151,
#                     0.10259974747896194,
#                     0.4563862085342407
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.78837651014328,
#                 "det_bbox": [
#                     0.8096663355827332,
#                     0.13970957696437836,
#                     0.8518355488777161,
#                     0.19218473136425018
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             },
#             {
#                 "classid": 3,
#                 "confidence": 0.7020183205604553,
#                 "det_bbox": [
#                     0.006818659603595734,
#                     0.0,
#                     0.034003712236881256,
#                     0.028355583548545837
#                 ],
#                 "label": "ship",
#                 "scan": "global"
#             }
#         ]
#     }
# }

# %% [markdown]
# ## Run inference and draw
#
# In this example we will draw the bounding boxes into the images
#
# This requires OpenCV2 and matplotlib

# %%
# %matplotlib inline

# %%
import os
import glob
import json
import boto3
import sagemaker
import cv2

# for displaying images at jupyter notebooks
from matplotlib import pyplot as plt

ALLOWED_EXTENSIONS = set(['png', 'jpg', 'jpeg', 'gif', 'webp', 'bmp'])

def getFiles(base):
    if os.path.isfile(base):
        return [base]
    else:
        return glob.glob(os.path.join(base, '**'), recursive=True)

def drawBB(
    image, header, x, y, xmax, ymax, color=(255, 0, 0), thickness=4*2, text_thickness=1*2,
    text_size=0.8*2, font=cv2.FONT_HERSHEY_PLAIN, footer=""
):
    # bounding box
    cv2.rectangle(image, (x, y), (xmax, ymax), color, thickness)
    
    # header text
    if header != '':
        (text_width, text_height) = cv2.getTextSize(header, font, fontScale=text_size, thickness=text_thickness)[0]
        
        cv2.rectangle(
            image,
            (max(0, int(x-(thickness/2))), max(0, int(y-5-text_height-(thickness/2)))),
            (int(x+text_width+(thickness/2)), int(y)),
            color,
            cv2.FILLED
        )
        
        cv2.putText(image, header, (max(0, x), max(0, y-5)), font, text_size, (0,0,0), text_thickness, cv2.LINE_AA)
        
    if footer != "":
        (footer_width, footer_height) = cv2.getTextSize(footer, font, fontScale=text_size, thickness=text_thickness)[0]
        
        cv2.rectangle(
            image,
            ( int(x-(thickness/2)), int(ymax+(thickness/2)) ),
            ( int(x+footer_width+(thickness/2)), int(ymax+footer_height+(thickness/2)) ),
            color,
            cv2.FILLED
        )
        
        cv2.putText(image, footer, ( x, int(ymax+12+(thickness/2)) ), font, text_size, (0,0,0), text_thickness, cv2.LINE_AA)

# initalize client
sagemaker = boto3.client(
    'runtime.sagemaker',
    region_name='us-east-2'
)

flist = getFiles(INPUT_PATH)
print("Processing: {} files...".format(len(flist)))

for fpath in flist:
    ext = fpath.split('.')[-1].lower() if '.' in fpath else None
    
    # skip unsupported / invalid file extensions
    if ext is None or ext not in ALLOWED_EXTENSIONS:
        continue
    
    # load input
    with open(fpath, 'rb') as fh:
        payload = fh.read()

    # invoke inference
    result = sagemaker.invoke_endpoint(
            EndpointName=ENDPOINT,
            ContentType='image/{}'.format(ext),
            Body=bytearray(payload))
    
    # parse response to json
    response = json.loads(result['Body'].read().decode())
    img = cv2.imread(fpath, 1)
    (height, width, channels) = img.shape
    
    try:
        for det in response['input.jpg']['detections']:
            xmin = det['det_bbox'][0] * width
            ymin = det['det_bbox'][1] * height
            xmax = det['det_bbox'][2] * width
            ymax = det['det_bbox'][3] * height
            
            drawBB(img, '{}@{:.2f}'.format(det['label'], det['confidence']), int(xmin), int(ymin), int(xmax), int(ymax))
    # skip when there's no detections
    except:
        pass
    
    # show image in jupyter
    fig, ax = plt.subplots(figsize=(int(1.05 * height / 100), int(1.05 * width / 100)), dpi=80)
    ax.imshow(img, interpolation='nearest')
    plt.show()
    plt.close()
    
    # ..or just save to disk
    # cv2.imwrite('/path/to/output.jpg', img)
